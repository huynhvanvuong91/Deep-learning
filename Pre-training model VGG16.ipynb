# %%
import keras
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\vuong.huynh\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions

# %%
from keras.models import Sequential
from scipy.misc import imread
get_ipython().magic('matplotlib inline')
from keras.layers import Dense

# %%
#from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers import Input, Dense, Convolution2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D, Dropout
from keras.layers import Dropout, Flatten, Activation, BatchNormalization, regularizers

# %%
from sklearn.preprocessing import LabelBinarizer
import keras
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils.np_utils import to_categorical
K.set_image_dim_ordering('th')

# %%
from keras import layers, models, optimizers, metrics, losses

# %%
import cv2

# %%
import glob
import os

# %%
from keras.applications import vgg16 as keras_vgg16
from keras.models import Model
from keras.layers import Dense, Flatten, Input
from keras.optimizers import SGD, RMSprop, Adam

# %%
folder_train = 'F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/Fruit-Images-Dataset-master/Training/'
folder_test = 'F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/Fruit-Images-Dataset-master/Validation/'

# %%
x_train = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 64X64/Train.npy')
y_train = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 64X64/Train_lables.npy')

# %%
y_train_lbl = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 64X64/Train_lables.npy')

# %%
x_test = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 64X64/Test.npy')
y_test = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 64X64/Test_labels.npy')

# %%
y_test_lbl = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 64X64/Test_labels.npy')

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X=LabelEncoder()
y_train = labelencoder_X.fit_transform(y_train)
y_test=labelencoder_X.transform(y_test)

# %%
from keras import utils as np_utils
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
img_rows, img_cols = 64, 64 # Resolution of inputs
channel = 3
num_classes = 70 
batch_size = 64 
nb_epoch = 50

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(3,64,64)))
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(4096, activation='relu'))
#model.add(Dropout(0.25))
model.add(Dense(70, activation='softmax'))
# Out:
# C:\Users\vuong.huynh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\vuong.huynh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   """
# C:\Users\vuong.huynh\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
#   if __name__ == '__main__':
# C:\Users\vuong.huynh\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
modelVGG = model
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.9, amsgrad=False)
modelVGG .compile(optimizer=adam, loss=losses.mean_squared_error,metrics=[metrics.categorical_accuracy])

# %%
MoHinhTrainmodelVGG  = modelVGG.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(x_test, y_test))
# Out:
# Train on 35133 samples, validate on 11804 samples
# Epoch 1/50
# 35133/35133 [==============================] - 233s 7ms/step - loss: 0.0135 - categorical_accuracy: 0.1003 - val_loss: 0.0114 - val_categorical_accuracy: 0.3405
# Epoch 2/50
# 35133/35133 [==============================] - 190s 5ms/step - loss: 0.0066 - categorical_accuracy: 0.6557 - val_loss: 0.0065 - val_categorical_accuracy: 0.6796
# Epoch 3/50
# 35133/35133 [==============================] - 189s 5ms/step - loss: 0.0029 - categorical_accuracy: 0.8622 - val_loss: 0.0048 - val_categorical_accuracy: 0.7699
# Epoch 4/50
# 35133/35133 [==============================] - 189s 5ms/step - loss: 0.0017 - categorical_accuracy: 0.9190 - val_loss: 0.0044 - val_categorical_accuracy: 0.7928
# Epoch 5/50
# 35133/35133 [==============================] - 188s 5ms/step - loss: 0.0012 - categorical_accuracy: 0.9387 - val_loss: 0.0040 - val_categorical_accuracy: 0.8128
# Epoch 6/50
# ...

# %%
def DoThiTiLeLoi(MoHinhSauTrain):
    history_dict = MoHinhSauTrain.history
    train_acc = history_dict['categorical_accuracy']
    train_loss = history_dict['loss']
  
    val_acc = history_dict['val_categorical_accuracy']
    val_loss = history_dict['val_loss']
  
    epochs = range(1, len(train_acc) + 1)
  
    plt.plot(epochs, train_loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
DoThiTiLeLoi(MoHinhTrainmodelVGG)

# %%
image_size =64

# %%
def get_im(path):
    #Đọc dữ liệu ảnh màu sử dụng thư viện opencv
    #Hàm imread chuyển đổi hình ảnh sang mảng
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    #img = cv2.imread(path, cv2.COLOR_BGR2RGB)
    # resize ảnh về cùng kích thước
    resized = cv2.resize(img, (image_size, image_size))
    return resized

# %%
def ConvertTenImage(TenTraiCay_Training):
    TenTraiCayPredict = []
    NameImagePre=""
    for ten in range(len(TenTraiCay_Training)):
        if NameImagePre != TenTraiCay_Training[ten]:
            NameImagePre = TenTraiCay_Training[ten]
            TenTraiCayPredict.append(NameImagePre)
    return np.asarray(TenTraiCayPredict)

# %%
TenTraiCaySuDungPredict = ConvertTenImage(y_train_lbl)

# %%
def TenTraiCayPredict(LablesName, ViTri):
    return LablesName[ViTri]

# %%
def DemSoLuongMauUngVoiTungTrai(LoaiTrai,TongSoFile):
    SoLuong=[]
    for TenTrai in range(len(LoaiTrai)):
        Dem=0;
        for DemTrai in range(len(TongSoFile)):
            if(LoaiTrai[TenTrai]==TongSoFile[DemTrai]):
                Dem = Dem + 1
        SoLuong.append(Dem)            
    return np.asarray(SoLuong)

# %%
SoLuong = DemSoLuongMauUngVoiTungTrai(TenTraiCaySuDungPredict,y_train_lbl)

# %%
for i in range(len(SoLuong)):
    print(TenTraiCaySuDungPredict[i]," : ", SoLuong[i])
# Out:
# Apple Braeburn  :  492
# Apple Golden 1  :  492
# Apple Golden 2  :  492
# Apple Golden 3  :  481
# Apple Granny Smith  :  492
# Apple Red 1  :  492
# Apple Red 2  :  492
# Apple Red 3  :  429
# Apple Red Delicious  :  490
# Apple Red Yellow  :  492
# Apricot  :  492
# Avocado  :  427
# Avocado ripe  :  491
# Banana  :  490
# Banana Red  :  490
# Cactus fruit  :  490
# Cantaloupe 1  :  492
# Cantaloupe 2  :  492
# Carambula  :  490
# Cherry 1  :  492
# Cherry 2  :  738
# Cherry Rainier  :  738
# Clementine  :  490
# Cocos  :  490
# Dates  :  490
# Granadilla  :  490
# Grape Pink  :  492
# Grape White  :  490
# Grape White 2  :  490
# Grapefruit Pink  :  490
# Grapefruit White  :  492
# Guava  :  490
# Huckleberry  :  490
# Kaki  :  490
# Kiwi  :  466
# Kumquats  :  490
# Lemon  :  492
# Lemon Meyer  :  490
# Limes  :  490
# Litchi  :  490
# Mandarine  :  490
# Mango  :  490
# Maracuja  :  490
# Melon Piel de Sapo  :  738
# Mulberry  :  492
# Nectarine  :  492
# Orange  :  479
# ...

# %%
def ImagePredict(path):
    dataPre=[]
    #imgPre = cv2.imread(path,cv2.IMREAD_ANYCOLOR)
    imgPre =get_im(path)
    imgPre = img_to_array(imgPre)
    dataPre.append(imgPre)
    dataPredict=np.array(dataPre, dtype=np.uint8)
    dataPredict = np.array(dataPredict, dtype="float") / 255.0
    return dataPredict

# %%
def HienThiKetQuaDuDoan(MoHinh,folder,Hang, Cot,NumImage, figsize=(20,10)):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    i=1
    demImage=0
    figs = plt.figure(figsize=figsize)
    NameImage=""
    #for sq in sequence_folder[start:end][:limit]:
    for sq in sequence_folder:
        sq = sq.replace('\\', '/')
        lables = sq.split('/')[-2]
        if NameImage != lables:
            NameImage = lables
            demImage=0
        if NameImage == lables:
            demImage+=1
        if demImage < NumImage:
            if i<(Hang*Cot):
                img = cv2.imread(sq,cv2.COLOR_BGR2RGB)
                
                ResultPr = MoHinh.predict(ImagePredict(sq))
                max_indexImage = np.argmax(ResultPr[0])
                LabelPred = TenTraiCayPredict(TenTraiCaySuDungPredict,max_indexImage)
                # Pick the first image for each label.
                plt.subplot(Hang, Cot, i)  # A grid of 8 rows x 8 columns
                #print(i)
                plt.axis('off')
                plt.title(lables+":"+LabelPred, fontsize=8)
                i += 1
                _ = plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
HienThiKetQuaDuDoan(modelVGG,folder_test,15,8,4)

# %%
def DuDoanFullData(MoHinh,folder):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    Dem=0
    for sq in sequence_folder:
        sq = sq.replace('\\', '/')
        lablesD = sq.split('/')[-2]
        img = cv2.imread(sq,cv2.COLOR_BGR2RGB)
        ResultPr = MoHinh.predict(ImagePredict(sq))
        max_indexImage = np.argmax(ResultPr[0])
        LabelPred = TenTraiCayPredict(TenTraiCaySuDungPredict,max_indexImage)
        if LabelPred==lablesD:
            Dem+=1
    return Dem,len(sequence_folder),Dem/len(sequence_folder)

# %%
def DuDoanFullDataRecall(MoHinh,folder):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    Dem=0
    lblData=[]
    lblPre=[]
    for sq in sequence_folder:
        sq = sq.replace('\\', '/')
        lablesData = sq.split('/')[-2]
        img = cv2.imread(sq,cv2.COLOR_BGR2RGB)
        ResultPr = MoHinh.predict(ImagePredict(sq))
        max_indexImage = np.argmax(ResultPr[0])
        LabelPred = TenTraiCayPredict(TenTraiCaySuDungPredict,max_indexImage)
        lblData.append(lablesData)
        lblPre.append(LabelPred)
    return lblData,lblPre

# %%
# Tỉ lệ dự đoán đúng trên tập Train
SoLuongDuDoanDungTrain,SoLuongTongTrain,TiLeTrain = DuDoanFullData(modelVGG,folder_train)
print("Số lượng tổng: ",str(SoLuongTongTrain)," Số lượng dự đoán đúng: ",str(SoLuongDuDoanDungTrain)," Tỉ lệ: ",str(TiLeTrain*100))
# Tỉ lệ dự đoán đúng trên tập Test
SoLuongDuDoanDungTest,SoLuongTongTest,TiLeTest = DuDoanFullData(modelVGG,folder_test)
print("Số lượng tổng: ",str(SoLuongTongTest)," Số lượng dự đoán đúng: ",str(SoLuongDuDoanDungTest)," Tỉ lệ: ",str(TiLeTest*100))
# Out:
# Số lượng tổng:  35133  Số lượng dự đoán đúng:  34431  Tỉ lệ:  98.00187857569807
# Số lượng tổng:  11804  Số lượng dự đoán đúng:  10377  Tỉ lệ:  87.91087766858692

# %%
from sklearn.metrics import classification_report
LabelDataTrain,LabelPredTrain = DuDoanFullDataRecall(modelVGG,folder_train)

# %%
print(classification_report(LabelDataTrain,LabelPredTrain))
# Out:
#                      precision    recall  f1-score   support
#
#      Apple Braeburn       1.00      1.00      1.00       492
#      Apple Golden 1       0.97      1.00      0.98       492
#      Apple Golden 2       1.00      1.00      1.00       492
#      Apple Golden 3       1.00      1.00      1.00       481
#  Apple Granny Smith       1.00      1.00      1.00       492
#         Apple Red 1       1.00      1.00      1.00       492
#         Apple Red 2       1.00      1.00      1.00       492
#         Apple Red 3       0.99      1.00      0.99       429
# Apple Red Delicious       1.00      1.00      1.00       490
#    Apple Red Yellow       1.00      1.00      1.00       492
#             Apricot       1.00      1.00      1.00       492
#             Avocado       1.00      1.00      1.00       427
#        Avocado ripe       1.00      1.00      1.00       491
#              Banana       1.00      1.00      1.00       490
# ...

# %%
LabelData,LabelPred = DuDoanFullDataRecall(modelVGG,folder_test)
print(classification_report(LabelData,LabelPred))
# Out:
#                      precision    recall  f1-score   support
#
#      Apple Braeburn       0.63      0.72      0.67       164
#      Apple Golden 1       0.95      0.79      0.86       164
#      Apple Golden 2       0.88      1.00      0.94       164
#      Apple Golden 3       0.61      1.00      0.76       161
#  Apple Granny Smith       0.75      0.77      0.76       164
#         Apple Red 1       0.62      0.38      0.47       164
#         Apple Red 2       0.83      0.54      0.66       164
#         Apple Red 3       0.71      0.47      0.56       144
# Apple Red Delicious       1.00      1.00      1.00       166
#    Apple Red Yellow       1.00      0.82      0.90       164
#             Apricot       0.73      0.93      0.82       164
#             Avocado       1.00      1.00      1.00       143
#        Avocado ripe       0.97      1.00      0.98       166
#              Banana       0.64      0.81      0.71       166
# ...

# %% [markdown]
# # Pre-training model VGG16

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(3, 64, 64))

# %%
for layer in base_model.layers:
    #chỉ đào tạo các bộ phân loại (các lớp FC) layer.trainable = False
    #Training va cap nhat tat ca layer.trainable = True 
    #Cho lớp trong model.layers [: 5]: # đóng băng 5 lớp đầu tiên layer.trainable = False.
    layer.trainable = True

# %%
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dense(70, activation='softmax')(x)
modelN_VGG16 = Model(base_model.input, x)

# %%
for layer in modelN_VGG16.layers:
    layer.trainable = True

# %%
modelN_VGG16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 3, 64, 64)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 32, 32)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 32, 32)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 32, 32)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 128, 16, 16)       0
# ...

# %%
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.9, amsgrad=False)
modelN_VGG16.compile(optimizer=adam, loss=losses.mean_squared_error,metrics=[metrics.categorical_accuracy])

# %%
MoHinhTrainmodelN_VGG16 = modelN_VGG16.fit(x_train, y_train, batch_size=batch_size, epochs=50, verbose=1, validation_data=(x_test, y_test))
# Out:
# Train on 35133 samples, validate on 11804 samples
# Epoch 1/50
# 35133/35133 [==============================] - 149s 4ms/step - loss: 0.0131 - categorical_accuracy: 0.1343 - val_loss: 0.0111 - val_categorical_accuracy: 0.3216
# Epoch 2/50
# 35133/35133 [==============================] - 148s 4ms/step - loss: 0.0086 - categorical_accuracy: 0.5363 - val_loss: 0.0078 - val_categorical_accuracy: 0.6020
# Epoch 3/50
# 35133/35133 [==============================] - 148s 4ms/step - loss: 0.0058 - categorical_accuracy: 0.7132 - val_loss: 0.0062 - val_categorical_accuracy: 0.7022
# Epoch 4/50
# 35133/35133 [==============================] - 197s 6ms/step - loss: 0.0046 - categorical_accuracy: 0.7774 - val_loss: 0.0058 - val_categorical_accuracy: 0.7093
# Epoch 5/50
# 35133/35133 [==============================] - 157s 4ms/step - loss: 0.0041 - categorical_accuracy: 0.8052 - val_loss: 0.0055 - val_categorical_accuracy: 0.7345
# Epoch 6/50
# ...

# %%
DoThiTiLeLoi(MoHinhTrainmodelN_VGG16)

# %%
# Tỉ lệ dự đoán đúng trên tập Train
SoLuongDuDoanDungTrainN,SoLuongTongTrainN,TiLeTrainN = DuDoanFullData(modelN_VGG16,folder_train)
print("Số lượng tổng: ",str(SoLuongTongTrainN)," Số lượng dự đoán đúng: ",str(SoLuongDuDoanDungTrainN)," Tỉ lệ: ",str(TiLeTrainN*100))
# Tỉ lệ dự đoán đúng trên tập Test
SoLuongDuDoanDungTestN,SoLuongTongTestN,TiLeTestN = DuDoanFullData(modelN_VGG16,folder_test)
print("Số lượng tổng: ",str(SoLuongTongTestN)," Số lượng dự đoán đúng: ",str(SoLuongDuDoanDungTestN)," Tỉ lệ: ",str(TiLeTestN*100))
# Out:
# Số lượng tổng:  35133  Số lượng dự đoán đúng:  31798  Tỉ lệ:  90.50750007115818
# Số lượng tổng:  11804  Số lượng dự đoán đúng:  9488  Tỉ lệ:  80.37953236191122

# %%
from sklearn.metrics import classification_report

# %%
LabelDataTrainN,LabelPredTrainN = DuDoanFullDataRecall(modelN_VGG16,folder_train)

# %%
print(classification_report(LabelDataTrainN,LabelPredTrainN))
# Out:
#                      precision    recall  f1-score   support
#
#      Apple Braeburn       0.71      0.83      0.77       492
#      Apple Golden 1       0.97      1.00      0.98       492
#      Apple Golden 2       1.00      1.00      1.00       492
#      Apple Golden 3       1.00      1.00      1.00       481
#  Apple Granny Smith       1.00      1.00      1.00       492
#         Apple Red 1       0.70      0.92      0.79       492
#         Apple Red 2       0.80      0.93      0.86       492
#         Apple Red 3       0.85      0.71      0.77       429
# Apple Red Delicious       0.93      0.83      0.88       490
#    Apple Red Yellow       1.00      0.30      0.47       492
#             Apricot       0.79      0.93      0.85       492
#             Avocado       0.99      1.00      1.00       427
#        Avocado ripe       0.99      1.00      0.99       491
#              Banana       0.93      1.00      0.96       490
# ...

# %%
LabelDataN,LabelPredN = DuDoanFullDataRecall(modelN_VGG16,folder_test)

# %%
print(classification_report(LabelDataN,LabelPredN))
# Out:
#                      precision    recall  f1-score   support
#
#      Apple Braeburn       0.46      0.36      0.41       164
#      Apple Golden 1       0.85      0.66      0.75       164
#      Apple Golden 2       1.00      1.00      1.00       164
#      Apple Golden 3       0.77      0.61      0.68       161
#  Apple Granny Smith       0.73      1.00      0.85       164
#         Apple Red 1       0.64      0.62      0.63       164
#         Apple Red 2       0.73      0.49      0.59       164
#         Apple Red 3       0.17      0.14      0.15       144
# Apple Red Delicious       0.96      0.98      0.97       166
#    Apple Red Yellow       0.78      0.50      0.61       164
#             Apricot       0.95      0.84      0.89       164
#             Avocado       0.99      0.87      0.93       143
#        Avocado ripe       0.85      0.99      0.92       166
#              Banana       0.75      0.64      0.69       166
# ...

# %% [markdown]
# # Pre-training Resnet50

# %%
def getImage(path, With, High):
    return load_img(path, target_size=(With, High))

# %%
def load_sequence(folder):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    train_img = []
    TenTraiCay = []
    for sq in sequence_folder:
        #print(sq.replace('\\', '/'))
        sq = sq.replace('\\', '/')
        lables = sq.split('/')[-2]
        image = getImage(sq,224,224)
        image = img_to_array(image)
        #image = image.astype('float32')
        #image  /=255.0
        #image_batch = np.expand_dims(image, axis=0)
        #image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
        train_img.append(image)
        TenTraiCay.append(lables)
    return np.array(train_img), np.asarray(TenTraiCay)

# %%
train_image,label_train=load_sequence(folder_train)
test_image,label_test=load_sequence(folder_test)

# %%
train_image.shape
# Out:
# (35133, 3, 224, 224)

# %%
train_image = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Train.npy')
label_train = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Train_lables.npy')

# %%
test_image = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Test.npy')
label_test = np.load('F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Test_labels.npy')

# %%
#d='F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Train'
#np.save(d,train_image)

# %%
#d1='F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Train_lables'
#np.save(d1,label_train)

# %%
#d2='F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Test'
#np.save(d2,test_image)

# %%
#d3='F:/8_Machine Learning/Bai tap Deeplearning/2_CNN/DATA 224X224/Test_labels'
#np.save(d3,label_test)

# %%
label_trainNew = label_train

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X=LabelEncoder()
y_label_train = labelencoder_X.fit_transform(label_train)
y_label_test=labelencoder_X.transform(label_test)

# %%
from keras import utils as np_utils
y_label_train = np_utils.to_categorical(y_label_train)
y_label_test = np_utils.to_categorical(y_label_test)

# %%
from keras.applications import inception_v3, resnet50, mobilenet

# %%
#Load the ResNet50 model
resnet_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-a71c41cc0e1b> in <module>()
#       1 #Load the ResNet50 model
# ----> 2 resnet_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(3, 224, 224))
#
# ~\Anaconda3\lib\site-packages\keras_applications\resnet50.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes)
#     214                       strides=(2, 2),
#     215                       padding='valid',
# --> 216                       name='conv1')(x)
#     217     x = layers.BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
#     218     x = layers.Activation('relu')(x)
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     430                                          '`layer.build(batch_input_shape)`')
#     431                 if len(input_shapes) == 1:
# ...

# %%
for layer in resnet_model.layers:
    #chỉ đào tạo các bộ phân loại (các lớp FC) layer.trainable = False
    #Training va cap nhat tat ca layer.trainable = True 
    #Cho lớp trong model.layers [: 5]: # đóng băng 5 lớp đầu tiên layer.trainable = False.
    layer.trainable = True

# %%
x = resnet_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dense(70, activation='softmax')(x)
model_resnet = Model(resnet_model.input, x)

# %%
for layer in model_resnet.layers:
    layer.trainable = True

# %%
model_resnet.summary()

# %%
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.9, amsgrad=False)
model_resnet.compile(optimizer=adam, loss=losses.mean_squared_error,metrics=[metrics.categorical_accuracy])

# %%
MoHinhTrainmodel_resnet = model_resnet.fit(train_image, y_label_train, batch_size=batch_size, epochs=10, verbose=1, validation_data=(test_image, y_label_test))

# %%
def get_im224(path):
    #Đọc dữ liệu ảnh màu sử dụng thư viện opencv
    #Hàm imread chuyển đổi hình ảnh sang mảng
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    #img = cv2.imread(path, cv2.COLOR_BGR2RGB)
    # resize ảnh về cùng kích thước
    resized = cv2.resize(img, (224, 224))
    return resized

# %%
def ConvertTenImage224(TenTraiCay_Training):
    TenTraiCayPredict = []
    NameImagePre=""
    for ten in range(len(TenTraiCay_Training)):
        if NameImagePre != TenTraiCay_Training[ten]:
            NameImagePre = TenTraiCay_Training[ten]
            TenTraiCayPredict.append(NameImagePre)
    return np.asarray(TenTraiCayPredict)

# %%
TenTraiCaySuDungPredict224 = ConvertTenImage224(label_trainNew)

# %%
def TenTraiCayPredict224(LablesName, ViTri):
    return LablesName[ViTri]

# %%
def ImagePredict224(path):
    dataPre=[]
    #imgPre = cv2.imread(path,cv2.IMREAD_ANYCOLOR)
    imgPre =get_im224(path)
    imgPre = img_to_array(imgPre)
    dataPre.append(imgPre)
    return np.array(dataPre)

# %%
def HienThiKetQuaDuDoan224(MoHinh,folder,Hang, Cot,NumImage, figsize=(20,10)):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    i=1
    demImage=0
    figs = plt.figure(figsize=figsize)
    NameImage=""
    #for sq in sequence_folder[start:end][:limit]:
    for sq in sequence_folder:
        sq = sq.replace('\\', '/')
        lables = sq.split('/')[-2]
        if NameImage != lables:
            NameImage = lables
            demImage=0
        if NameImage == lables:
            demImage+=1
        if demImage < NumImage:
            if i<(Hang*Cot):
                img = cv2.imread(sq,cv2.COLOR_BGR2RGB)
                
                ResultPr = MoHinh.predict(ImagePredict224(sq))
                max_indexImage = np.argmax(ResultPr[0])
                LabelPred = TenTraiCayPredict224(TenTraiCaySuDungPredict224,max_indexImage)
                # Pick the first image for each label.
                plt.subplot(Hang, Cot, i)  # A grid of 8 rows x 8 columns
                #print(i)
                plt.axis('off')
                plt.title(lables+":"+LabelPred, fontsize=8)
                i += 1
                _ = plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
HienThiKetQuaDuDoan224(modelVGG,folder_test,15,8,4)

# %%
def DuDoanFullData224(MoHinh,folder):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    Dem=0
    for sq in sequence_folder:
        sq = sq.replace('\\', '/')
        lablesD = sq.split('/')[-2]
        img = cv2.imread(sq,cv2.COLOR_BGR2RGB)
        ResultPr = MoHinh.predict(ImagePredict224(sq))
        max_indexImage = np.argmax(ResultPr[0])
        LabelPred = TenTraiCayPredict224(TenTraiCaySuDungPredict224,max_indexImage)
        if LabelPred==lablesD:
            Dem+=1
    return Dem,len(sequence_folder),Dem/len(sequence_folder)

# %%
def DuDoanFullDataRecall224(MoHinh,folder):
    sequence_folder = glob.glob(os.path.join(folder, '*/*'))
    Dem=0
    lblData=[]
    lblPre=[]
    for sq in sequence_folder:
        sq = sq.replace('\\', '/')
        lablesData = sq.split('/')[-2]
        img = cv2.imread(sq,cv2.COLOR_BGR2RGB)
        ResultPr = MoHinh.predict(ImagePredict224(sq))
        max_indexImage = np.argmax(ResultPr[0])
        LabelPred = TenTraiCayPredict224(TenTraiCaySuDungPredict224,max_indexImage)
        lblData.append(lablesData)
        lblPre.append(LabelPred)
    return lblData,lblPre

# %%
# Tỉ lệ dự đoán đúng trên tập Train
SoLuongDuDoanDungTrain224,SoLuongTongTrain224,TiLeTrain224 = DuDoanFullData224(modelVGG,folder_train)
print("Số lượng tổng: ",str(SoLuongTongTrain224)," Số lượng dự đoán đúng: ",str(SoLuongDuDoanDungTrain224)," Tỉ lệ: ",str(TiLeTrain224*100))
# Tỉ lệ dự đoán đúng trên tập Test
SoLuongDuDoanDungTest224,SoLuongTongTest224,TiLeTest224 = DuDoanFullData224(modelVGG,folder_test)
print("Số lượng tổng: ",str(SoLuongTongTest224)," Số lượng dự đoán đúng: ",str(SoLuongDuDoanDungTest224)," Tỉ lệ: ",str(TiLeTest224*100))

# %%
from sklearn.metrics import classification_report
LabelDataTrain224,LabelPredTrain224 = DuDoanFullDataRecall224(modelVGG,folder_train)

# %%
print(classification_report(LabelDataTrain224,LabelPredTrain224))

# %%
LabelData224,LabelPred224 = DuDoanFullDataRecall224(modelVGG,folder_test)
print(classification_report(LabelData224,LabelPred224))

# %%
from keras.applications import inception_v3, resnet50, mobilenet

# %%
#Load the Inception_V3 model
inception_model = inception_v3.InceptionV3(weights='imagenet', include_top=False, input_shape=(3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-79b3090ff6e2> in <module>()
#       1 #Load the Inception_V3 model
# ----> 2 inception_model = inception_v3.InceptionV3(weights='imagenet', include_top=False, input_shape=(3, 224, 224))
#
# ~\Anaconda3\lib\site-packages\keras_applications\inception_v3.py in InceptionV3(include_top, weights, input_tensor, input_shape, pooling, classes)
#     165         channel_axis = 3
#     166
# --> 167     x = conv2d_bn(img_input, 32, 3, 3, strides=(2, 2), padding='valid')
#     168     x = conv2d_bn(x, 32, 3, 3, padding='valid')
#     169     x = conv2d_bn(x, 64, 3, 3)
#
# ~\Anaconda3\lib\site-packages\keras_applications\inception_v3.py in conv2d_bn(x, filters, num_row, num_col, padding, strides, name)
#      78         padding=padding,
#      79         use_bias=False,
# ---> 80         name=conv_name)(x)
# ...

# %%
#Load the ResNet50 model
resnet_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(3, 128, 128))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-9c3764ae3240> in <module>()
#       1 #Load the ResNet50 model
# ----> 2 resnet_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(3, 128, 128))
#
# ~\Anaconda3\lib\site-packages\keras_applications\resnet50.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes)
#     196                                       data_format=backend.image_data_format(),
#     197                                       require_flatten=include_top,
# --> 198                                       weights=weights)
#     199
#     200     if input_tensor is None:
#
# ~\Anaconda3\lib\site-packages\keras_applications\imagenet_utils.py in _obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
# ...

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(3, 64, 64))
